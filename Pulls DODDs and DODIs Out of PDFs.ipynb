# %% [markdown]
# # Pulls DoDDs and DODIs Out Of PDFs

# %% [markdown]
# #### This reads in PDFs, pulls certain phrases from them which correspond to DoDDs and DODIs, and then finds those documents on google, downloads them, and puts the names and links in an Excel file

# %% [markdown]
# ### Libraries

# %%
import PyPDF2
import os
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup
#for this specific enviroment
#newDir='/home/abigailhaddad/PDFs'
newDir=r"C:\Users\admin\Documents\Python Scripts\cleaningPDFs"
#os.mkdir(newDir)
os.chdir(newDir)

# %% [markdown]
# ### Functions

# %%
def pullTextFromPDF(fileToRead):
	pdfFileObj = open(fileToRead, 'rb')
	pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
	pageCount=pdfReader.numPages
	textOutput=""
	for pageNumber in range(0, pageCount):
		pageOutput=pdfReader.getPage(pageNumber).extractText()
		textOutput=textOutput+pageOutput
	return(textOutput)

def cleanText(textString):
	cleanedText=textString.replace("\n", "")
	return(cleanedText)

def cleanString(myString):
	myString=re.sub(r'[\(\)]', '', str(myString))
	return(myString)

def extractPhrases(cleanedText):
	listOfWords=cleanedText.split()
	regPhrases=[]
	ourWantPhrases=["dodi", "dodd", "directive", "instruction"]
	for wordNumber in range(0, len(listOfWords)):
		if any(phrase in listOfWords[wordNumber].lower() for phrase in ourWantPhrases):
			miniList=listOfWords[wordNumber-1:wordNumber+2]
			cleanPhrase=" ".join(miniList)
			if len(re.sub("\D", "", cleanPhrase))>0 and 'DoD' in cleanPhrase:
				startNumber=cleanPhrase.find('DoD')
				endnumber=re.match('.+([0-9])[^0-9]*$', cleanPhrase).start(1)+1
				regPhrases.append(cleanPhrase[startNumber:endnumber])
	regPhrases=list(map(cleanString, regPhrases))
	return(list(set(regPhrases)))


def takeFileNameGetPhrases(fileToRead):
	textOutput=pullTextFromPDF(fileToRead)
	cleanedText=cleanText(textOutput)
	phrases=extractPhrases(cleanedText)
	return(phrases)

def makeSumChartbyAgency(dictOfPhrases):
    listOfAgencies=[i.split()[0] for i in dictOfPhrases.keys()]
    listOfLists=[]
    for phrases in dictOfPhrases.values():
        longPhrase=[i for i in phrases if len(i)>0]
        phrase=[i.split()[-1] for i in longPhrase]
        listOfLists.append(phrase)
    countOfRegs=[len(set(i)) for i in listOfLists]
    dictOfCounts=dict(zip(listOfAgencies, countOfRegs))
    s  = pd.Series(dictOfCounts,index=dictOfCounts.keys())
    return(s)

def getUniqueList(dictOfPhrases):
    oneList=[]
    for phrases in dictOfPhrases.values():
        longPhrase=[i for i in phrases if len(i)>0]
        phrase=[i.split()[-1] for i in longPhrase]
        for bit in phrase:
            oneList.append(bit)
    oneUniqueList=list(set(oneList))
    return(oneUniqueList)

def getFirstPDFLink(fileName):
    linkSearch=fileName+"site:www.esd.whs.mil"
    search = "http://google.com/search?q=" + linkSearch
    r = requests.get(search)
    soup = BeautifulSoup(r.text, "html.parser")
    found=0
    for link in soup.findAll('a'):
        if "pdf" in (link.get('href')) and found==0:
            found=1
            pdfLink=(link.get('href'))
    return(pdfLink)
    
def cleanBadLink(pdfLink):
    startNumber=pdfLink.find('http')
    endNumber=pdfLink.find('.pdf')+4
    return(pdfLink[startNumber:endNumber])

def pullPDF(cleanLink):
    r = requests.get(cleanLink, allow_redirects=True)
    name=cleanLink.split("/")[-1]
    open(name, 'wb').write(r.content)

def fromNameGetFile(fileName):
    try:
        pdfLink=getFirstPDFLink(fileName)
        print(pdfLink)
        cleanLink=cleanBadLink(pdfLink)
        print(cleanLink)
        pullPDF(cleanLink)
        print("got pdf")
        print("")
    except:
        pass

# %% [markdown]
# ### Get Phrases From PDFs

# %%
listOfPDFs=[i for i in os.listdir() if "pdf" in i.lower()]
listOfPhrases=list(map(takeFileNameGetPhrases, listOfPDFs))
dictOfPhrases=dict(zip(listOfPDFs, listOfPhrases))
s=makeSumChartbyAgency(dictOfPhrases)
s
# Out:
# 203008p.pdf        12
# 204002_2014.pdf    18
# 416550e.pdf         2
# 501502p.pdf        13
# 502501p.pdf        15
# 511121p.pdf         2
# 512409p.pdf         7
# 514402p.pdf         9
# 523020p.pdf         7
# dtype: int64

# %%
### Write List do Excel File

# %%
writer = pd.ExcelWriter('output.xlsx')
for PDF in listOfPDFs:
    s.to_excel(writer, "Summary")
    tabName=PDF.split(" ")[0]
    print(tabName)
    mySeries=pd.Series(dictOfPhrases[PDF])
    print(mySeries)
    if len(mySeries)>0:
        mySeries.to_excel(writer, tabName)
writer.save()
# Out:
# 203008p.pdf
# 0     DoD Instruction 5230.29
# 1                DoDD 5106.01
# 2     DoD Instruction 4140.01
# 3     DoD Instruction 2040.02
# 4     DoD Instruction 2030.08
# 5                 DoDI 5505.2
# 6       DoD Directive 5105.72
# 7                DoDI 4140.01
# 8                DoDI 2040.02
# 9        DoD Directive 5111.1
# 10               DoDI 2030.08
# 11    DoD Instruction 5505.02
# 12               DoDI 5230.29
# 13               DoDI 5230.24
# 14    DoD Instruction 5230.24
# 15                DoDD 5111.1
# 16               DoDD 5105.72
# 17               DoDI 4160.28
# 18      DoD Directive 5106.01
# 19    DoD Instruction 4160.28
# 20      DoD Directive 5230.25
# 21               DoDD 5230.25
# dtype: object
# 204002_2014.pdf
# 0         DoD Directive 5230.11
# 1          DoD Directive 5530.3
# 2                  DoDI 5200.39
# 3                  DoDI 5025.01
# 4       DoD Instruction 2010.06
# 5       DoD Instruction 2040.02
# 6     DoD Instruction O-5240.24
# 7       DoD Instruction 2000.25
# 8       DoD Instruction 5000.02
# 9         DoD Directive 5230.20
# 10        DoD Directive 5134.01
# 11      DoD Instruction 5200.39
# 12                 DoDI 2010.06
# 13               DoDI O-5240.24
# 14        DoD Directive 5105.60
# 15              DoD Directive 9
# 16                 DoDI 2040.02
# 17      DoD Instruction 5025.01
# 18         DoD Directive 5111.1
# 19        DoD Directive 5111.11
# 20      DoD Instruction 5230.24
# 21                 DoDI 5230.24
# 22                 DoDI 5000.02
# 23                 DoDI 2000.25
# 24        DoD Directive 5106.01
# 25        DoD Directive 5230.25
# dtype: object
# 416550e.pdf
# 0             DoDD 4165.50
# 1     DoD Directive 5101.1
# 2    DoD Directive 4165.50
# 3              DoDD 5101.1
# dtype: object
# 501502p.pdf
# 0                 DoDD 5015.2
# 1        DoD Directive 5015.2
# 2     DoD Instruction 3020.42
# 3                DoDI 6025.18
# 4                DoDI 8550.01
# 5            DoD Directive 54
# 6                DoDD 5400.11
# 7                DoDD 5144.02
# 8                DoDI 5010.40
# 9                 DoDD 5101.1
# 10               DoDI 5015.02
# 11               DoDI 8115.02
# 12               DoDI 8320.02
# 13               DoDD 5100.03
# 14               DoDI 3020.42
# 15      DoD Directive 5144.02
# dtype: object
# 502501p.pdf
# 0
# 1     DoD Instruction 5230.29
# 2                DoDI 5025.01
# 3           DoD. DoDI 5025.01
# 4                DoDI 8910.01
# 5                DoDD 5110.04
# 6       DoD Directive 5230.09
# 7     DoD Instruction 1400.25
# 8                DoDI 5025.13
# 9                 DoDD 5101.1
# 10      DoD Directive 5105.53
# 11    DoD Instruction 5025.13
# 12       DoD Directive 5101.1
# 13      DoD Directive 5105.82
# 14    DoD Instruction 5545.02
# 15    DoD Instruction 5025.01
# 16              DoDDs 5105.82
# 17               DoDD 5230.09
# 18    DoD Instruction 5015.02
# 19    DoD Instruction 8520.02
# 20               DoDI 8520.02
# 21               DoDI 5230.29
# 22               DoDD 5100.01
# 23               DoDI 1400.25
# 24               DoDI 7750.07
# 25    DoD Instruction 8910.01
# 26               DoDI 5015.02
# 27      DoD Directive 5110.04
# 28    DoD Instruction 7750.07
# 29      DoD Directive 5100.01
# dtype: object
# 511121p.pdf
# 0    DoD Instruction 5025.01
# 1               DoDD 5111.21
# dtype: object
# 512409p.pdf
# 0       DoD Directive 5124.02
# 1                DoDD 5124.02
# 2                DoDD 3200.15
# 3                DoDD 5100.01
# 4       DoD Directive 1322.18
# 5     DoD Instruction 5025.01
# 6     DoD Instruction 8910.01
# 7                DoDI 5025.01
# 8       DoD Directive 3200.15
# 9                DoDI 8910.01
# 10               DoDD 1322.18
# 11      DoD Directive 5100.01
# 12               DoDD 5124.09
# dtype: object
# 514402p.pdf
# 0        DoD Directive 5530.3
# 1     DoD Instruction 5025.01
# 2                 DoDD 5530.3
# 3                DoDI 8500.01
# 4     DoD Instruction 8550.01
# 5       DoD Directive 5105.19
# 6                DoDI 8550.01
# 7     DoD Instruction 8910.01
# 8                DoDI 5025.01
# 9                DoDD 5144.02
# 10               DoDI 8910.01
# 11                DoDD 5101.1
# 12               DoDI 8000.01
# 13      DoD Directive 8000.01
# 14               DoDD 5105.19
# 15    DoD Instruction 8500.01
# 16       DoD Directive 5101.1
# 17      DoD Directive 5144.02
# dtype: object
# 523020p.pdf
# 0    DoD Directive 5230.11
# 1     DoD Directive 5530.3
# 2                DoDD 5230
# 3     DoD Directive 5230.9
# 4    DoD Directive 5230.20
# 5    DoD Directive 5230.25
# 6             DoDD 5230.20
# 7    DoD Directive 5230.24
# dtype: object

# %% [markdown]
# ### Look at Unique Count

# %%
oneList=getUniqueList(dictOfPhrases)
(len(oneList))
# Out:
# 60

# %% [markdown]
# ### Download Sample Names

# %%
testNames=mySeries
testNames
# Out:
# 0    DoD Directive 5230.11
# 1     DoD Directive 5530.3
# 2                DoDD 5230
# 3     DoD Directive 5230.9
# 4    DoD Directive 5230.20
# 5    DoD Directive 5230.25
# 6             DoDD 5230.20
# 7    DoD Directive 5230.24
# dtype: object

# %%
for thing in testNames:
    fromNameGetFile(thing)
# Out:
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540011p.pdf&sa=U&ved=0ahUKEwiH6LDN0fbhAhW2D2MBHYEEAycQFggoMAM&usg=AOvVaw1sdGKrJ0EO4um1Yh8pxHZK
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540011p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf&sa=U&ved=0ahUKEwid1fHN0fbhAhWB2-AKHTj-CM8QFggjMAM&usg=AOvVaw0kkuiN7LkMuzL5lnb_ZZ2e
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf&sa=U&ved=0ahUKEwiE6r_O0fbhAhUC8hQKHaxIBgAQFgghMAQ&usg=AOvVaw2dWvmUJJFdzqxq1DcpNLkc
# http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/Portals/54/Documents/DD/Issuances/dodi/523029p.pdf&sa=U&ved=0ahUKEwirpo3P0fbhAhV98OAKHQmSCToQFggdMAE&usg=AOvVaw0UnfX2tq_AVbxUvPGnBlDW
# http://www.esd.whs.mil/Portals/54/Documents/DD/Issuances/dodi/523029p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf&sa=U&ved=0ahUKEwiVucPP0fbhAhUIlhQKHX4aCJ4QFggjMAM&usg=AOvVaw014va9DwSxt6UvlJfYdUF4
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/portals/54/documents/dd/issuances/dodd/523025p.pdf&sa=U&ved=0ahUKEwjBkPTP0fbhAhWjBWMBHSrQA-kQFggeMAI&usg=AOvVaw36lqLJAop1yQJ_hKnC4Jz9
# http://www.esd.whs.mil/portals/54/documents/dd/issuances/dodd/523025p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540011p.pdf&sa=U&ved=0ahUKEwjOrK_Q0fbhAhUp3OAKHf3GA6MQFggjMAM&usg=AOvVaw1Max8fdAiORq1WqyGOWt5L
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540011p.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/523027_dodi_2016.pdf&sa=U&ved=0ahUKEwj5wOTQ0fbhAhWkAGMBHfuUBrQQFggjMAI&usg=AOvVaw0ObZZjYMt6LxGSNI41hFm-
# http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/523027_dodi_2016.pdf
# got pdf

# %% [markdown]
# ### Flatten Dictionary With All of the Document Names and Pull Them

# %%
allPhrases = list(set(list([item for sublist in listOfPhrases for item in sublist])))
allCleanLinks=list(map(fromNameGetFile, allPhrases))
# Out:
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/502501p.pdf&sa=U&ved=0ahUKEwibpIOA0vbhAhXdUBUIHfJSCP0QFggtMAQ&usg=AOvVaw0e-qAVdpF-uFdxikEqhsJ_
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/502501p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/891001p.pdf&sa=U&ved=0ahUKEwjOkbuA0vbhAhUBonEKHaDmBXIQFggUMAA&usg=AOvVaw3aoFbuHuXWWmPZcliz2dhG
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/891001p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf&sa=U&ved=0ahUKEwjknvqA0vbhAhWTTxUIHTmyCcYQFggjMAM&usg=AOvVaw2qbjCwyXpMO-PyQ-YvAN-p
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540011p.pdf&sa=U&ved=0ahUKEwjkpaSB0vbhAhXCRBUIHQ6dBvEQFggjMAI&usg=AOvVaw3PC5uG4OUyOmWT0pddItJ3
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540011p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf%3Fver%3D2018-11-06-140911-727&sa=U&ved=0ahUKEwjX-s6B0vbhAhVKTRUIHbHRBpwQFggjMAM&usg=AOvVaw0OQ7p_kJItj2BcFeJrFHxF
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510553p.pdf&sa=U&ved=0ahUKEwjr0PyB0vbhAhV5RxUIHePZDaIQFggUMAA&usg=AOvVaw0T2Ys5JKz2XvkYr29Gb20T
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510553p.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/502513p.pdf%3Fver%3D2018-05-31-081817-327&sa=U&ved=0ahUKEwj-yLSC0vbhAhXHUxUIHRjHBvMQFggeMAE&usg=AOvVaw2c0ErKxJE-OpzqoFs_a5Lz
# http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/502513p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf&sa=U&ved=0ahUKEwj66euC0vbhAhWsQxUIHfiaCsoQFggjMAM&usg=AOvVaw22yi8vYRYbRCgQ1bQJ8hJp
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/520039p.pdf&sa=U&ved=0ahUKEwjSuZmD0vbhAhVdTBUIHRcXCkUQFggUMAA&usg=AOvVaw2RRN43Y0_1o3NpYbidWrO3
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/520039p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510560p.pdf&sa=U&ved=0ahUKEwjomceD0vbhAhWuVBUIHeSBAT8QFggUMAA&usg=AOvVaw0XNiDCcGYWkw63J_48IYKJ
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510560p.pdf
# got pdf
#
# /url?q=https://navytribe.files.wordpress.com/2015/11/comomaginst-4000-2.pdf&sa=U&ved=0ahUKEwjjwZCE0vbhAhULVRUIHQKLDr0QFghAMAs&usg=AOvVaw0mwpK8j8yttLqqcbi1F9Ts
# https://navytribe.files.wordpress.com/2015/11/comomaginst-4000-2.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/817001p.pdf&sa=U&ved=0ahUKEwj0sciE0vbhAhXBXhUIHZ8TCikQFggeMAI&usg=AOvVaw1HewKe0xuzLRoKHvYvbGtw
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/817001p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/501502p.pdf&sa=U&ved=0ahUKEwiuooCF0vbhAhUEUBUIHdg0DG8QFggjMAI&usg=AOvVaw0BsAOA2DSBczb4oR0zLyqu
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/501502p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/320015p.pdf&sa=U&ved=0ahUKEwjyjrWF0vbhAhXVQhUIHf6ADQwQFggUMAA&usg=AOvVaw0esRWyqKR-oehV7Qadtqub
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/320015p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/817001p.pdf&sa=U&ved=0ahUKEwj_8PGF0vbhAhVRqHEKHYgTDnQQFggjMAI&usg=AOvVaw0XMI38qNjEIJdCnRlvq7uL
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/817001p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/817001p.pdf&sa=U&ved=0ahUKEwjw16mG0vbhAhV1t3EKHStOCfQQFggjMAI&usg=AOvVaw1T3grHnoVZYTVghEHCELw0
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/817001p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/523024p.pdf&sa=U&ved=0ahUKEwj7geSG0vbhAhUoVBUIHUlFCWoQFggjMAI&usg=AOvVaw2hfLdk56sSDyj34RT-W2Ix
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/523024p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/416568p.pdf%3Fver%3D2018-09-19-074001-503&sa=U&ved=0ahUKEwj81ZqH0vbhAhXRRxUIHSX3D0EQFggtMAQ&usg=AOvVaw18BQEmhWCBORgbikgaZKt_
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/416568p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/775007p.pdf&sa=U&ved=0ahUKEwi269aH0vbhAhU7SRUIHT4TC40QFggtMAQ&usg=AOvVaw19BMVn85ROYUPeLC9ZUk0d
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/775007p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/portals/54/documents/dd/issuances/dodi/850001_2014.pdf&sa=U&ved=0ahUKEwiA2o6I0vbhAhWyURUIHbF3CuYQFggUMAA&usg=AOvVaw2iwKC0F-3_hIlTPtz3O3lE
# https://www.esd.whs.mil/portals/54/documents/dd/issuances/dodi/850001_2014.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/portals/54/documents/dd/issuances/dodd/523025p.pdf&sa=U&ved=0ahUKEwjRgcaI0vbhAhWZURUIHWFnDRwQFggeMAI&usg=AOvVaw2kMxeS6cZInVYFBO_NUowF
# http://www.esd.whs.mil/portals/54/documents/dd/issuances/dodd/523025p.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/portals/54/documents/dd/issuances/dodd/523025p.pdf&sa=U&ved=0ahUKEwjVpPeI0vbhAhWztHEKHTmVDRAQFggZMAE&usg=AOvVaw2qklcAa2MBrKKfU9S6Mi0N
# http://www.esd.whs.mil/portals/54/documents/dd/issuances/dodd/523025p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf&sa=U&ved=0ahUKEwj_p6eJ0vbhAhWmRhUIHQzUA0EQFggjMAM&usg=AOvVaw3rl9PxEeuWscgUwKVEClOm
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/132218p.pdf&sa=U&ved=0ahUKEwiY7uiJ0vbhAhXBUBUIHaG8B2sQFggUMAA&usg=AOvVaw13EzqW65iHGJbxHIwx2bNx
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/132218p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510601p.pdf&sa=U&ved=0ahUKEwjHlqOK0vbhAhXXQRUIHQYOBk8QFggeMAE&usg=AOvVaw3CvflcWXtSw9MWuVKcKu22
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510601p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/portals/54/documents/dd/issuances/dodi/850001_2014.pdf&sa=U&ved=0ahUKEwjsuNqK0vbhAhV8XhUIHWJpAVUQFggeMAE&usg=AOvVaw1m9v1tDCgvF487IPzmgX6-
# https://www.esd.whs.mil/portals/54/documents/dd/issuances/dodi/850001_2014.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/502501p.pdf&sa=U&ved=0ahUKEwi9y5OL0vbhAhWSQhUIHcDGDEoQFggjMAI&usg=AOvVaw1HsKB8SeJbpBYcKGWY5iYR
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/502501p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/520039p.pdf&sa=U&ved=0ahUKEwiygdKL0vbhAhWeQxUIHXz2DkAQFggUMAA&usg=AOvVaw3PwGcOm6MkaJD4FbZGQzUH
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/520039p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/813001p.pdf%3Fver%3D2019-04-11-094441-463&sa=U&ved=0ahUKEwj8q4-M0vbhAhV2ShUIHV7gAzsQFggoMAM&usg=AOvVaw0r-QHYGnMm0Wm2O0alNjWb
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/813001p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/511004p.pdf&sa=U&ved=0ahUKEwi5gcmM0vbhAhWOQxUIHVrvAAsQFggUMAA&usg=AOvVaw2fPZAjV5liI3TxRgeUtBGg
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/511004p.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/502513p.pdf%3Fver%3D2018-05-31-081817-327&sa=U&ved=0ahUKEwjIvYGN0vbhAhXIQRUIHezkAscQFggeMAE&usg=AOvVaw3P3Cc9mmdYWbZZbTkPXTKd
# http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/502513p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/501502p.pdf&sa=U&ved=0ahUKEwjqscKN0vbhAhVnSRUIHQfGAfwQFggUMAA&usg=AOvVaw1jOP_lOzID_L756yrr5Fmr
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/501502p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/302042p.pdf&sa=U&ved=0ahUKEwi74faN0vbhAhUNVBUIHc_eCJ8QFggUMAA&usg=AOvVaw2rdwrfbiu3NccP3UIu_OEh
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/302042p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510582p.pdf&sa=U&ved=0ahUKEwjamLiO0vbhAhXtVRUIHTrfAI4QFggUMAA&usg=AOvVaw3pIf5jQiK_hSfBYYhRw49_
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510582p.pdf
# got pdf
#
# /url?q=https://strategicmedicaltraining.com/2018/03/28/http-www-esd-whs-mil-portals-54-documents-dd-issuances-dodi-132224p-pdfver2018-03-16-074408-137/&sa=U&ved=0ahUKEwiV6_SO0vbhAhXZRhUIHQJ8BsAQwW4IPjAK&usg=AOvVaw2zK8Bn-zBWP_XmwQNUiI1J
#
# /url?q=http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf&sa=U&ved=0ahUKEwj53I6P0vbhAhWCURUIHaa9BvIQFgghMAQ&usg=AOvVaw0HcvusLHXp0o67mFUgtUDV
# http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510582p.pdf&sa=U&ved=0ahUKEwiphMyP0vbhAhURuHEKHXLsBOcQFggUMAA&usg=AOvVaw0vBaksQuoU4Fgs62K75GFx
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/510582p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/817001p.pdf&sa=U&ved=0ahUKEwj7jPmP0vbhAhX_SBUIHbpcAjEQFggjMAI&usg=AOvVaw21sSOZCBBuEbm4WW7r4Huk
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/817001p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf%3Fver%3D2018-11-06-140911-727&sa=U&ved=0ahUKEwjArqqQ0vbhAhVVShUIHZjnDjkQFggUMAA&usg=AOvVaw1bWEMEsZvhkBZ_IiA3AZtM
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/302042p.pdf&sa=U&ved=0ahUKEwi98dCQ0vbhAhWAQxUIHWP4C8AQFggUMAA&usg=AOvVaw1pUG0TL692m0_5pq3t_Zgr
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/302042p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/523024p.pdf&sa=U&ved=0ahUKEwiowPWQ0vbhAhUdShUIHVa2BvcQFggZMAE&usg=AOvVaw1aKEAoRQ86utB7HUG_E-8f
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/523024p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf%3Fver%3D2018-11-06-140911-727&sa=U&ved=0ahUKEwiB6buR0vbhAhUCQxUIHf7jAe0QFgghMAQ&usg=AOvVaw0PNctNYlnFOx0aZmC6fXJU
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf%3Fver%3D2018-11-06-140911-727&sa=U&ved=0ahUKEwjKu-aR0vbhAhXIVBUIHWd5BG8QFggjMAI&usg=AOvVaw1ENspEa6uhtKtkb_KnS4Qh
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/416550e.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/523027_dodi_2016.pdf&sa=U&ved=0ahUKEwjn9oyS0vbhAhUVonEKHX_5BD8QFggjMAI&usg=AOvVaw1_91XQVGQvGg3wPac_LveH
# http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/523027_dodi_2016.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf&sa=U&ved=0ahUKEwjH79aS0vbhAhXXQhUIHfJdDakQFggjMAM&usg=AOvVaw3tkk2O-1gLTVywHFFh6FxM
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf
# got pdf
#
# /url?q=http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/140025/1400.25-V530.pdf&sa=U&ved=0ahUKEwiy-IaT0vbhAhXURhUIHeZMB8oQFggyMAU&usg=AOvVaw058-XVEtQgDnaEhXZ3Mnrf
# http://www.esd.whs.mil/Portals/54/Documents/DD/issuances/140025/1400.25-V530.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/811502p.pdf&sa=U&ved=0ahUKEwiVg8yT0vbhAhUJTRUIHToQC-oQFggUMAA&usg=AOvVaw2QKiBE7xlmBdUR34OE2DnC
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/811502p.pdf
# got pdf
#
# /url?q=https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf&sa=U&ved=0ahUKEwikrKuU0vbhAhWQQRUIHTl8AXYQFggjMAM&usg=AOvVaw1tjQnUN4PJDsbHOVgf7kUa
# https://www.esd.whs.mil/Portals/54/Documents/DD/issuances/dodd/540007p.pdf
# got pdf

# %% [markdown]
# ### Puts The Report Names and Links in an Excel File

# %%
df=pd.DataFrame({"Report": allPhrases, "Link": allCleanLinks})
df.to_excel("Links.xlsx")
